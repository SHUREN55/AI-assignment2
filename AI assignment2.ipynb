# %%
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
from numpy import *

# %%
#Python program to solve quadratic equation using math module
import cmath
print("The Quadratic Equation is of form ax2 + bx+ c\n")  
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
c = int(input("Enter the value of c: "))
  
# Computing the Discriminat value
D = (b**2) - (4*a*c)
  
# find two results
root1 = (-b - cmath.sqrt(D))/(2 * a)
root2 = (-b + cmath.sqrt(D))/(2 * a)
  
# printing the results
print("The roots are: ")
print(root1)
print(root2)
# Out:
# The Quadratic Equation is of form ax2 + bx+ c

# %% [markdown]
# ![1646445146%281%29.png](attachment:1646445146%281%29.png)
